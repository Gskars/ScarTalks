# %% [markdown]
# <a href="https://colab.research.google.com/github/Gskars/ScarTaks/blob/main/ScarTalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata
api_key= userdata.get("SECRET_KEY")

GOOGLE_API_KEY= "YOUR_API_KEY_HERE"
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
generation_config = {
    "candidate_count": 1,
    "temperature": 0.5 ,
}

# %%
safety_settings = {
    "HARASSMENT": "BLOCK_NONE",
    "HATE": "BLOCK_NONE",
    "SEXUAL": "BLOCK_NONE",
    "DANGEROUS" : "BLOCK_NONE"
}

# %%
model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
chat = model.start_chat ( history = [])

# %%
def get_idioma():
    idiomas = ["Inglês", "Francês", "Alemão", "Russo", "Italiano", "Islandês", "Espanhol", "Mandarim", "Norueguês", "Japonês"]

    while True:
        print("\nEscolha o idioma que deseja estudar:")
        for i, idioma in enumerate(idiomas, 1):
            print(f"{i}. {idioma}")

        try:
            escolha = int(input("\nDigite o número do idioma desejado: ").strip())
            if 1 <= escolha <= len(idiomas):
                return idiomas[escolha - 1]
            else:
                print("\nEscolha inválida! Por favor, escolha um número de 1 a 10.")
        except ValueError:
            print("\nEntrada inválida! Por favor, digite um número válido.")

def get_assunto():
    return input("\nQual assunto você quer aprender? ").strip()

def gerar_prompt_exemplos(assunto, tipo, idioma):
    if tipo == "frases":
        prompt = f"""
        Você é um professor de {idioma} especialista no assunto "{assunto}". Formate toda a resposta em MARKDOWN.
        Siga estas regras rigorosamente:

        **Estrutura da Resposta:**
        1. Título nível 2: **Exemplos sobre "{assunto}"**
        2. Primeiro parágrafo: explicação do significado ou contexto (1 linha)
        3. Lista numerada de 10 itens com:
           - Frase em {idioma} em *itálico*
           - Tradução entre parênteses
           - Exemplo:
             *1. "Look up the address." (Procure o endereço.)*

        **Regras:**
        - Use contextos variados: cotidiano, profissional, viagens
        - Mantenha as traduções simples e literais
        - Não use formatação extra além do especificado
        """
        return prompt

    elif tipo == "dialogos":
        prompt = f"""
        Você é um professor de {idioma} especialista no assunto "{assunto}". Formate toda a resposta em MARKDOWN.
        Siga estas regras rigorosamente:

        **Estrutura da Resposta:**
        1. Título nível 2: **Diálogos sobre "{assunto}"**
        2. Primeiro parágrafo: explicação breve do significado ou contexto
        3. Para cada um dos 5 diálogos:
           - Subtítulo: **Diálogo [Número] (Contexto)**
           - Personagens fictícios (ex: Alice, Bob, Carol)
           - 2-4 falas por diálogo
           - Cada fala deve conter o assunto
           - Tradução entre parênteses após cada fala

        **Exemplo de Formato:**
        * Alice: Can you look up the recipe? (Você pode procurar a receita?)
        * Bob: I'll look it up online now. (Vou procurar online agora.)

        **Contextos Sugeridos:**
        - Cotidiano - Trabalho - Viagens - Educação - Tecnologia
        """
        return prompt

def gerar_frases_e_dialogos(opcao, idioma):
    assunto = get_assunto()

    print("\nEscolha uma opção:")
    print("1. Gerar 10 frases com o assunto")
    print("2. Gerar 5 diálogos com o assunto")

    opcao = input("\nDigite a opção desejada: ").strip()

    if opcao == "1":
        prompt = gerar_prompt_exemplos(assunto, "frases", idioma)
        response = chat.send_message(prompt)  # Substituir pela sua API de IA
        print(f"\n{response.text}\n")

    elif opcao == "2":
        prompt = gerar_prompt_exemplos(assunto, "dialogos", idioma)
        response = chat.send_message(prompt)  # Substituir pela sua API de IA
        print(f"\n{response.text}\n")

# Função principal
def main():
    while True:
        idioma = get_idioma()
        print(f"\nVocê escolheu o idioma: {idioma}")

        # A lógica é a mesma para o Inglês e para outros idiomas
        gerar_frases_e_dialogos("1", idioma)  # Usando a opção 1 como exemplo para mostrar o fluxo

        continuar = input("\nDeseja escolher outro idioma? (s/n): ").strip().lower()
        if continuar != 's':
            print("\nObrigado por usar o chatbot! Bons estudos!")
            break

if __name__ == "__main__":
    main()
# Out:
# Escolha o idioma que deseja estudar:
# 1. Inglês
# 2. Francês
# 3. Alemão
# 4. Russo
# 5. Italiano
# 6. Islandês
# 7. Espanhol
# 8. Mandarim
# 9. Norueguês
# 10. Japonês
#
# Digite o número do idioma desejado: 1
#
# Você escolheu o idioma: Inglês
#
# Qual assunto você quer aprender? Compras no mercado
#
# Escolha uma opção:
# 1. Gerar 10 frases com o assunto
# 2. Gerar 5 diálogos com o assunto
#
# Digite a opção desejada: 2
#
# ## Diálogos sobre "Compras no mercado"
#
# Os diálogos a seguir apresentam cenários comuns relacionados a compras no mercado, demonstrando vocabulário e frases essenciais.
#
# ### Diálogo 1 (Mercado diário)
#
# - Alice: Boa tarde, senhor. Quero comprar algumas frutas. (Good afternoon, sir. I'd like to buy some fruits.)
# - Vendedor: Claro, senhora. Temos uma grande variedade. (Of course, madam. We have a wide variety.)
#
# ### Diálogo 2 (Compras para uma festa)
#
# - Bob: Precisamos comprar muitos alimentos para a festa. (We need to buy a lot of food for the party.)
# - Carol: Vamos fazer uma lista do que precisamos. (Let's make a list of what we need.)
#
# ### Diálogo 3 (Compras em viagem)
#
# - Dave: Onde podemos encontrar um mercado local? (Where can we find a local market?)
# - Emily: Há um pequeno mercado perto do nosso hotel. (There's a small market near our hotel.)
#
# ### Diálogo 4 (Compras educacionais)
#
# - Professor: Para o projeto da próxima semana, vocês precisarão comprar alguns ingredientes específicos. (For next week's project, you will need to buy some specific ingredients.)
# - Aluno: Entendido. Vamos procurar no mercado. (Got it. We'll check the market.)
#
# ### Diálogo 5 (Compras tecnológicas)
#
# - Frank: Estou procurando um novo aplicativo para gerenciar minhas compras. (I'm looking for a new app to manage my groceries.)
# - Gerente: Temos alguns ótimos aplicativos disponíveis. (We have some great apps available.)
#
#
# Deseja escolher outro idioma? (s/n): s
#
# Escolha o idioma que deseja estudar:
# 1. Inglês
# 2. Francês
# 3. Alemão
# 4. Russo
# 5. Italiano
# 6. Islandês
# 7. Espanhol
# 8. Mandarim
# 9. Norueguês
# 10. Japonês
#
# Digite o número do idioma desejado: 7
#
# Você escolheu o idioma: Espanhol
#
# Qual assunto você quer aprender? Compras no pet shop
#
# Escolha uma opção:
# 1. Gerar 10 frases com o assunto
# 2. Gerar 5 diálogos com o assunto
#
# Digite a opção desejada: 2
#
# ## Diálogos sobre "Compras no pet shop"
#
# Os diálogos a seguir apresentam cenários comuns relacionados a compras em pet shops, demonstrando vocabulário e frases essenciais.
#
# ### Diálogo 1 (Compras de rotina)
#
# - Ana: Bom dia. Estou procurando comida para o meu gato. (Buenos días. Estoy buscando comida para mi gato.)
# - Vendedor: Claro, temos uma grande variedade. (Claro, tenemos una gran variedad.)
#
# ### Diálogo 2 (Preparação para viagem)
#
# - Beatriz: Vou viajar e preciso de uma transportadora para o meu cachorro. (Voy a viajar y necesito una transportadora para mi perro.)
# - Vendedor: Temos vários modelos disponíveis. (Tenemos varios modelos disponibles.)
#
# ### Diálogo 3 (Compras para um novo animal de estimação)
#
# - Carlos: Acabamos de adotar um filhote e precisamos comprar tudo. (Acabamos de adoptar un cachorro y necesitamos comprar todo.)
# - Vendedor: Parabéns! Podemos ajudá-los a encontrar tudo o que precisam. (¡Felicidades! Podemos ayudarles a encontrar todo lo que necesitan.)
#
# ### Diálogo 4 (Pesquisa educacional)
#
# - Professora: Para o projeto da próxima semana, vocês precisarão pesquisar diferentes tipos de alimentos para animais de estimação. (Para el proyecto de la próxima semana, necesitarán investigar diferentes tipos de alimentos para mascotas.)
# - Aluno: Vamos visitar uma pet shop para obter mais informações. (Vamos visitar una tienda de mascotas para obtener más información.)
#
# ### Diálogo 5 (Compras tecnológicas)
#
# - Daniel: Estou procurando um dispositivo de rastreamento GPS para o meu cachorro. (Estoy buscando un dispositivo de rastreo GPS para mi perro.)
# - Vendedor: Temos alguns modelos avançados que podem ajudá-lo a monitorar seu animal de estimação. (Tenemos algunos modelos avanzados que pueden ayudarle a monitorear a su mascota.)
#
#
# Deseja escolher outro idioma? (s/n): s
#
# Escolha o idioma que deseja estudar:
# 1. Inglês
# 2. Francês
# 3. Alemão
# 4. Russo
# 5. Italiano
# 6. Islandês
# 7. Espanhol
# 8. Mandarim
# 9. Norueguês
# 10. Japonês
#
# Digite o número do idioma desejado: 1
#
# Você escolheu o idioma: Inglês
#
# Qual assunto você quer aprender? Compras no pet shop
#
# Escolha uma opção:
# 1. Gerar 10 frases com o assunto
# 2. Gerar 5 diálogos com o assunto
#
# Digite a opção desejada: 1
#
# ## Exemplos sobre "Compras no pet shop"
#
# Aqui está uma lista de 10 frases em inglês com traduções para uso em compras em pet shops:
#
# 1. *Can I help you find anything?* (Posso ajudá-lo a encontrar alguma coisa?)
# 2. *I'm looking for food for my cat.* (Estou procurando comida para o meu gato.)
# 3. *Do you have any recommendations for a new puppy?* (Você tem alguma recomendação para um novo filhote?)
# 4. *I need a leash and collar for my dog.* (Preciso de uma guia e coleira para o meu cachorro.)
# 5. *Where can I find the cat litter?* (Onde posso encontrar a areia para gatos?)
# 6. *I'm traveling with my pet. Do you have any pet carriers?* (Estou viajando com meu animal de estimação. Vocês têm transportadoras para animais de estimação?)
# 7. *Can you recommend a good brand of pet food?* (Você pode recomendar uma boa marca de ração para animais de estimação?)
# 8. *I'm looking for a specific toy for my dog.* (Estou procurando um brinquedo específico para o meu cachorro.)
# 9. *Do you have any discounts for bulk purchases?* (Vocês têm algum desconto para compras em atacado?)
# 10. *Can you help me find a gift for my friend's new pet?* (Você pode me ajudar a encontrar um presente para o novo animal de estimação do meu amigo?)
#
#
# Deseja escolher outro idioma? (s/n): n
#
# Obrigado por usar o chatbot! Bons estudos!
